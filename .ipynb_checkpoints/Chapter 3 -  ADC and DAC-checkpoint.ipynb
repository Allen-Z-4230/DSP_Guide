# %% [markdown]
# Not a lot of code in this chapter. The following are some topics I've decided to create a program for.

# %% [markdown]
# Single Bit ADC & DAC - Delta Modulation + a step size optimizing function that I whipped up

# %%
# %pylab inline
import numpy as np
import scipy as sp
import scipy.io
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
filename = 'emodat-Copy1.mat'
file = scipy.io.loadmat(filename)
n = 100
x = file['data']
x = x[0]
x = x[0:n]
time = np.arange(0,n,1)
deltmod = np.zeros(n)
logic_state = np.zeros(n)

# %%
def one_bit_converter(signal,ss):
    running_voltage = 0
    for i in range(0,n):
        if running_voltage < signal[i]:
            running_voltage = running_voltage + ss
            deltmod[i] = running_voltage
            logic_state[i] = 1
        else:
            running_voltage = running_voltage - ss
            deltmod[i] = running_voltage
            logic_state[i] = 0
    return(deltmod)
def fidelity(step_size):
    hausen_x = list(zip(time,x))
    hausen_deltmod = list(zip(time,one_bit_converter(x,step_size)))
    hausen = scipy.spatial.distance.directed_hausdorff(hausen_x,hausen_deltmod)
    return hausen[0]
r = minimize(fidelity,5,method = 'Nelder-Mead')

# %%
one_bit_converter(x,r.x)
plt.plot(x)
plt.step(time,deltmod)
print(r.x,fidelity(r.x))
# Out:
# [5.76654053] 3.1022211105365494

# %%
plt.plot(logic_state, color = 'k')
